# %%
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Code get_data()

# %% [markdown]
# ## Create draft code in notebook

# %%
import os
import pandas as pd

# Build relative path to csv folder 
csv_path = '/Users/brunolajoie/code/lewagon/data-solutions/04-Decision-Science/data/csv' # Bad practice!
csv_path = '../../data/csv' # Mac OS version
csv_path = '..\\..\\data\\csv' # Windows version
csv_path = os.path.join('..','..','data','csv') # more robust to Linux/OS/Windows discrepency
csv_path

# %%
file_names = [f for f in os.listdir(csv_path) if f.endswith('.csv')]
file_names

# %%
key_names = []
for f in file_names:
    if f == 'product_category_name_translation.csv':
        key_names.append('product_category_name_translation')
    else:
        key_names.append(f[6:-12])
key_names

# %%
# Create the dictionary
data = {}
for k, f in zip(key_names, file_names):
    data[k] = pd.read_csv(os.path.join(csv_path, f))

data.keys()

# %% [markdown]
# ## Transfer logic to data/olist.py
#
# It should return the dictionary `data` upon calling it as per below
#
# ```python
# from olist.data import Olist
# Olist().get_data()
# ```
# - Take time to understand what happens when calling `Olist().get_data()`
# - Your method `get_data()` needs to be callable from various places (e.g your Terminal, this notebook, another notebook located elsewhere, etc...)
# - You can't use relative path this time as the current working directory `os.getcwd()` depends on where you run the code in the first place

# %%
# Test your code
from olist.data import Olist
Olist().get_data().keys()

# %% [markdown]
# # Let's build a business metric : Weekly Sales

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Goal**: Plot weekly sum of `payment_value` for delivered orders

# %% [markdown]
# ❓ **Step 1**: Pseudo code your process in English below before actually coding

# %% [markdown]
# ❓ **Step 2**: code your logic
