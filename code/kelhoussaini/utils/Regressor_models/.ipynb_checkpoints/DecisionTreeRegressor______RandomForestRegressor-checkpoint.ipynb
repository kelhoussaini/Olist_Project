# %% [markdown]
# # DecisionTreeRegressor

# %% [markdown]
# ## make_regression dataset

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import make_regression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import scale

X, y = make_regression( n_samples=5000, n_features=10)

X = scale(X)
y = scale(y)

#fractionner dataset (train-test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)


#instanciation
model_DTReg = DecisionTreeRegressor() #criterion= 'mse', random_state = 0

#training
model_DTReg.fit(X_train, y_train)

#calcule de précision
#print("R-squared score model_DTReg on Test_set",  model_DTReg.score( X_test, y_test))
print("R-squared score model_DTReg on Training_set",  model_DTReg.score( X_train, y_train))

y_pred = model_DTReg.predict(X_test)

mse = mean_squared_error(y_test, y_pred) 
print("MSE : ", mse)
print("RMSE: ", mse*(.5)) 
print("MAE : ", mean_absolute_error(y_test, y_pred) )
# Out:
# R-squared score model_DTReg on Training_set 1.0
# MSE :  0.34453318460731147
# RMSE:  0.17226659230365574
# MAE :  0.46945202653999935

# %%
#Prédiction
model_DTReg.predict( [10*[0]])
# Out:
# array([-0.17794074])

# %% [markdown]
# ## load_diabetes dataset

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import cross_val_score

X, y = load_diabetes(return_X_y=True)
X = scale(X)
y = scale(y)

#fractionner dataset (train-test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

#instanciation
model_DTReg = DecisionTreeRegressor()

#training
model_DTReg.fit( X_train, y_train)

print( cross_val_score(model_DTReg, X_train, y_train, cv=10).mean() )

#calcule de précision
#print("R-squared score model_DTReg on Test_set",  model_DTReg.score( X_test, y_test))
print("R-squared score model_DTReg on Training_set",  model_DTReg.score( X_train, y_train))

y_pred = model_DTReg.predict(X_test)

mse = mean_squared_error(y_test, y_pred) 
print("MSE : ", mse)
print("RMSE: ", mse*(.5)) 

#print("MAE : ", mean_absolute_error(y_test, y_pred) )
# Out:
# -0.202233355557557
# R-squared score model_DTReg on Training_set 1.0
# MSE :  0.9973774257262308
# RMSE:  0.4986887128631154

# %%
plt.figure(figsize=(19,7))


x_ax = range(len(y_test))
plt.plot(x_ax, y_test, 'r', label="original") # linewidth=1
plt.plot(x_ax, y_pred, 'b', label="predicted") # linewidth=1.1
plt.title("y-test and y-predicted data")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best') #,fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %% [markdown]
# **Attributs :**
#
# Pour le **DecisionTreeRegressor**, le paramètre criterion peut prendre l’une des valeurs suivantes :
#
# * mse : Correspond à l’erreur quadratique moyenne. Elle est égale à la réduction de la variance comme critère de sélection des caractéristiques.
#
# * freidman_mse : Correspond aussi à l’erreur quadratique moyenne mais avec le score d’amélioration de Friedman.
#
# * mae : Correspond à l’erreur moyenne absolue. Minimise la perte de L1 en utilisant la médiane de chaque nœud terminal.

# %% [raw]
# https://www.datatechnotes.com/2020/10/regression-example-with-decisiontreeregressor.html

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

X, y = load_diabetes(return_X_y=True)
X = scale(X)
y = scale(y)

#fractionner dataset (train-test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

#instanciation
model_RFReg = RandomForestRegressor(max_depth = 3) #  criterion='mse',

#training
model_RFReg.fit( X_train, y_train)

print( cross_val_score(model_RFReg, X_train, y_train, cv=10).mean() )

#calcule de précision
#print("R-squared score model_RFReg on Test_set",  model_RFReg.score( X_test, y_test))
print("R-squared score model_RFReg on Training_set",  model_RFReg.score( X_train, y_train))

y_pred = model_RFReg.predict(X_test)

mse = mean_squared_error(y_test, y_pred) 
print("MSE : ", mse)
print("RMSE: ", mse*(.5)) 
print("MAE : ", mean_absolute_error(y_test, y_pred) )
# Out:
# 0.4174289918856201
# R-squared score model_RFReg on Training_set 0.572493630186844
# MSE :  0.5436475737451992
# RMSE:  0.2718237868725996
# MAE :  0.6112152963324876

# %%
plt.figure(figsize=(19,7))


x_ax = range(len(y_test))
plt.plot(x_ax, y_test, 'r', label="original") # linewidth=1
plt.plot(x_ax, y_pred, 'b', label="predicted") # linewidth=1.1
plt.title("y-test and y-predicted data")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best') #,fancybox=True, shadow=True)
plt.grid(True)
plt.show()
